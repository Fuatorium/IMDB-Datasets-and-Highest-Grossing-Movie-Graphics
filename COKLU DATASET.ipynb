# %%
import pandas as pd

# %%
df = pd.read_csv("IMDB Dataset.csv")
df.head()
df.dropna(axis="columns",how="any").shape
df.tail(5)
# Out:
#                                                   review sentiment
# 49995  I thought this movie did a down right good job...  positive
# 49996  Bad plot, bad dialogue, bad acting, idiotic di...  negative
# 49997  I am a Catholic taught in parochial elementary...  negative
# 49998  I'm going to have to disagree with the previou...  negative
# 49999  No one expects the Star Trek movies to be high...  negative

# %%
df = pd.read_excel("TOP IMDB Movies.xlsx")
df.columns
df.dropna(axis="columns",how="any").shape
df.head()
# Out:
#    Unnamed: 0  Number                     Title  \
# 0           0     1.0         Avengers: Endgame
# 1           1     2.0              Gisaengchung
# 2           2     3.0               The Shining
# 3           3     4.0           The Dark Knight
# 4           4     5.0  The Shawshank Redemption
#
#                               Movie link  Rating  Runtime  \
# 0  https://www.imdb.com/title/tt4154796/     8.6  181 min
# 1  https://www.imdb.com/title/tt6751668/     8.5  132 min
# 2  https://www.imdb.com/title/tt0081505/     8.4  146 min
# 3  https://www.imdb.com/title/tt0468569/     9.0  152 min
# 4  https://www.imdb.com/title/tt0111161/     9.3  142 min
#
#                                      Genre      Votes  Metascore     Gross  \
# 0  \nAction, Adventure, Sci-Fi                558,276         78  $858.37M
# 1    \nComedy, Drama, Thriller                 29,523         92  $858.37M
# 2              \nDrama, Horror                798,352         66   $44.02M
# ...

# %%
df = pd.read_csv("IMDb Movies India.csv")
df.columns
df.shape
df.dropna(axis="columns",how="any").shape
df.head()
# Out:
#                                  Name    Year Duration            Genre  \
# 0                                         NaN      NaN            Drama
# 1  #Gadhvi (He thought he was Gandhi)  (2019)  109 min            Drama
# 2                         #Homecoming  (2021)   90 min   Drama, Musical
# 3                             #Yaaram  (2019)  110 min  Comedy, Romance
# 4                   ...And Once Again  (2010)  105 min            Drama
#
#    Rating Votes            Director       Actor 1             Actor 2  \
# 0     NaN   NaN       J.S. Randhawa      Manmauji              Birbal
# 1     7.0     8       Gaurav Bakshi  Rasika Dugal      Vivek Ghamande
# 2     NaN   NaN  Soumyajit Majumdar  Sayani Gupta   Plabita Borthakur
# 3     4.4    35          Ovais Khan       Prateik          Ishita Raj
# 4     NaN   NaN        Amol Palekar  Rajat Kapoor  Rituparna Sengupta
#
#            Actor 3
# 0  Rajendra Bhatia
# 1    Arvind Jangid
# 2       Roy Angana
# 3  Siddhant Kapoor
# ...

# %%
df = pd.read_csv("ChristopherNolan.csv")
df.columns
df.shape
df.dropna(axis="columns",how="any").shape
df.head()
# Out:
#    ﻿Year          Title  Runtime  Rated           Director  Released  \
# 0   1998      Following   69 min      R  Christopher Nolan   11/5/99
# 1   2000        Memento  113 min      R  Christopher Nolan   5/25/01
# 2   2002       Insomnia  118 min      R  Christopher Nolan   5/24/02
# 3   2005  Batman Begins  140 min  PG-13  Christopher Nolan   6/15/05
# 4   2006   The Prestige  130 min  PG-13  Christopher Nolan  10/20/06
#
#                                               Writer             Production  \
# 0                                  Christopher Nolan                    IFC
# 1  Christopher Nolan (screenplay), Jonathan Nolan...        Newmarket Films
# 2  Hillary Seitz (screenplay), Nikolaj Frobenius,...  Warner Bros. Pictures
# 3  Bob Kane (characters), David S. Goyer (story),...  Warner Bros. Pictures
# 4  Jonathan Nolan (screenplay), Christopher Nolan...   Buena Vista Pictures
#
#                                               Actors  \
# ...

# %%
df = pd.read_csv("IMDB.csv")
df.columns
df.shape
df.dropna(axis="columns",how="any").shape
df.head()
# Out:
#    Unnamed: 0                    Title  Rating TotalVotes     Genre1  \
# 0           1  12 Years a Slave�(2013)     8.1    496,092  Biography
# 1           2         127 Hours�(2010)     7.6    297,075  Adventure
# 2           3             50/50�(2011)     7.7    283,935     Comedy
# 3           4        About Time�(2013)     7.8    225,412     Comedy
# 4           5             Amour�(2012)     7.9     76,121      Drama
#
#       Genre2   Genre3  MetaCritic        Budget  Runtime  ...  Votes3044  \
# 0      Drama  History        96.0  $20,000,000   134 min  ...       �8.0
# 1  Biography    Drama        82.0  $18,000,000    94 min  ...       �7.5
# 2      Drama  Romance        72.0   $8,000,000   100 min  ...       �7.6
# 3      Drama  Fantasy         NaN  $12,000,000   123 min  ...       �7.6
# 4    Romance      NaN        94.0   $8,900,000   127 min  ...       �7.7
#
#    Votes3044M  Votes3044F  Votes45A  Votes45AM  Votes45AF  VotesIMDB  \
# ...
